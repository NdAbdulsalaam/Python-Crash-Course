# %%
num = 4

# %%
def classe(a):
    if num < 5:
        print("Number is less than 5")
    elif 5 <= num < 10:
        print("Number is btw 5 and 10")
    else:
        print("Number is greater than 10")

# %%
classe(12)
# Out:
# Number is greater than 10

# %%
def test():
    print("Ade")
    print("Ola")

# %%
test()
# Out:
# Ade
# Ola

# %%
num = 6
if num != 5:
    print("yes")
# Out:
# yes

# %%
for i in range(1, 5, 2):
    print(i)
# Out:
# 1
# 3

# %%
i = 6
rounds = 1
while i < 8:
    print(f"Round {rounds}")
    print(f"intial value: {i}")
    rounds += 1
    i -= 1
    print(f"final value: {i} \n")
# Out:
# Round 1
# intial value: 6
# final value: 5
#
# Round 2
# intial value: 5
# final value: 4
#
# Round 3
# intial value: 4
# final value: 3
#
# Round 4
# intial value: 3
# final value: 2
#
# Round 5
# intial value: 2
# final value: 1
#
# Round 6
# intial value: 1
# final value: 0
#
# Round 7
# intial value: 0
# final value: -1
#
# Round 8
# intial value: -1
# final value: -2
#
# Round 9
# intial value: -2
# final value: -3
#
# Round 10
# intial value: -3
# final value: -4
#
# Round 11
# intial value: -4
# final value: -5
#
# Round 12
# intial value: -5
# final value: -6
#
# Round 13
# intial value: -6
# final value: -7
#
# Round 14
# intial value: -7
# final value: -8
#
# Round 15
# intial value: -8
# final value: -9
#
# Round 16
# intial value: -9
# final value: -10
#
# Round 17
# intial value: -10
# final value: -11
#
# Round 18
# intial value: -11
# final value: -12
#
# Round 19
# intial value: -12
# final value: -13
#
# Round 20
# intial value: -13
# final value: -14
#
# Round 21
# ...
